# %% [markdown]
# # HR Employee Attrition Analysis\nPortfolio EDA using Python, Pandas and Matplotlib.

# %%
import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\n\ndf = pd.read_csv('data/hr_attrition_cleaned.csv')\ndf.head()

# %%
df.shape, df.isna().sum().sum(), df['Attrition'].value_counts()

# %%
df.groupby('Department')['AttritionFlag'].agg(['count','sum','mean']).sort_values('mean', ascending=False)

# %%
df.groupby('JobRole')['AttritionFlag'].agg(['count','sum','mean']).sort_values('mean', ascending=False)

# %%
df.groupby('OverTime')['AttritionFlag'].agg(['count','sum','mean'])

# %% [markdown]
# ## Conclusion\nThe strongest descriptive patterns should be treated as signals for further HR investigation rather than causal conclusions.
